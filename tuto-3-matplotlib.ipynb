# %% [markdown]
# import and inline matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# make a random variable

# %%
import numpy as np

# %%
N=10000
x = np.random.normal(size=N)

# %% [markdown]
# make a one-D histogram

# %%
plt.hist(x)
plt.show()

# %% [markdown]
# add a title to it

# %%
plt.hist(x)
plt.title('A distribution')
plt.show()

# %% [markdown]
# change the color

# %%
plt.hist(x, color='green')
plt.title('A distribution')
plt.show()

# %% [markdown]
# add a label

# %%
plt.hist(x, label='gaussian', color='red', bins=20)
plt.show()

# %% [markdown]
# where is the label ?

# %% [markdown]
# add a legend

# %%
plt.hist(x, color='pink',label='gaussian')
plt.title('A distribution')
plt.legend()
plt.show()

# %% [markdown]
# add another variable

# %%
y = np.random.random(N)

# %%
plt.hist(x, color='pink',label='gaussian')
plt.hist(y, color='red',label='flat')
plt.title('Distributions')
plt.legend()
plt.show()

# %% [markdown]
# change to the same binning

# %%
bins = np.linspace(-4, 4, 20)
plt.hist(x, color='violet',label='gaussian', bins=bins)
plt.hist(y, color='blue',label='flat', bins=bins)
plt.title('Distributions')
plt.legend()
plt.show()

# %% [markdown]
# make it transparent

# %%
bins = np.linspace(-4, 4, 20)
plt.hist(x, color='red',label='gaussian', bins=bins, alpha=0.5)
plt.hist(y, color='green',label='flat', bins=bins, alpha=0.5)
plt.title('Distributions')
plt.legend()
plt.show()

# %% [markdown]
# make a scatter plot

# %%
n=50
plt.figure(figsize=(10,10))
plt.scatter(x[:n],y[:n], s=100, color ='pink', alpha=0.5, label='one direction')
plt.scatter(y[-n:],x[-n:], s=100, color ='blue', alpha=0.5, label='other direction')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# A scatter plot with a circle drawn on top

# %%
n=50
plt.figure(figsize=(10,10))
plt.scatter(x[:n],y[:n], s=100, color ='pink', alpha=0.5, label='one direction')
plt.scatter(y[-n:],x[-n:], s=100, color ='blue', alpha=0.5, label='other direction')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.gcf().gca().add_artist( plt.Circle((0.5, 0.5), 0.7,color='g',  fill=False ) )
plt.legend()
plt.show()

# %% [markdown]
# http://matplotlib.org/
# http://matplotlib.org/examples/index.html

# %%
from keras.datasets import mnist
# Out:
# Using TensorFlow backend.

# %%
(train_data, train_target), (test_data, test_target) = mnist.load_data()

# %%
test_data.shape
# Out:
# (10000, 28, 28)

# %%
train_data_sq = train_data.reshape( (train_data.shape[0], 1,28,28 ) )

# %%
for inum in range( 2):
    plt.figure(figsize=(1,1))
    plt.imshow( train_data_sq[inum,0,...], )
    print "the target is",train_target[inum]
    #print train_target_N[inum]
    plt.show()
# Out:
# the target is 5
# the target is 0
